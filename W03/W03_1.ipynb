# %% [markdown]
# # W01 - 1 : 應用練習: 初步感受Python的威力

# %% [markdown]
# ## 快速使用套件，完成一個地圖應用

# %%
import pandas as pd

# %%
df = pd.read_csv("https://data.kcg.gov.tw/dataset/449e45d9-dead-4873-95a9-cc34dabbb3af/resource/fe3f93da-9673-4f7b-859c-9017d793f798/download/108.6.21.csv")

# %%
df.head()
# Out:
#     型式  行政區    場名            位置         緯度          經度           收費標準    大車  \
# 0   平面  甲仙區  甲仙林森    A區：林森路70號旁  23.082862  120.587988  小車計次(30元/6小時)   0.0
# 1  NaN  NaN   NaN    B區：林森路75號旁  23.082262  120.587394            NaN   NaN
# 2   平面  杉林區  大愛園區     A區:清水路中學巷  22.969360  120.542510              -  27.0
# 3  NaN  NaN   NaN  B區:和氣街二巷1號對面  22.966443  120.542328            NaN   NaN
# 4  NaN  NaN   NaN    C區:合心路&互愛街  22.962941  120.539572            NaN   NaN
#
#     小車   機車         營運/管理業者       聯絡電話                 履約起迄
# 0   35    0       歐特儀股份有限公司  903135731  113/04/01～119/03/31
# 1  NaN  NaN             NaN        NaN                  NaN
# 2  120    0  環球大宇宙太陽能工業有限公司  980889269  110/06/01～120/04/30
# 3  NaN  NaN             NaN        NaN                  NaN
# 4  NaN  NaN             NaN        NaN                  NaN

# %%
# 可以使用 `pip install folium` 安裝套件
# 使用 `pip install geocoder`

# %%
# 在colab用底下的安裝指令

#!pip install geocoder

# %%
import folium
import geocoder

# %%
# 使用 geocoder 取得特定住址的 GPS 座標
location = geocoder.osm('高雄市').latlng
# Out:
# Status code 403 from https://nominatim.openstreetmap.org/search: ERROR - 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/search?q=%E9%AB%98%E9%9B%84%E5%B8%82&format=jsonv2&addressdetails=1&limit=1

# %%
location

# %%
m = folium.Map(location=location, zoom_start=16)

# %%
for i, row in df.iterrows():
    try:
        folium.Marker([float(row['緯度']), float(row['經度'])], popup=row['場名']).add_to(m)
    except Exception as e:
        print(e.args)
# Out:
# ('Location values cannot contain NaNs.',)
# ('Location values cannot contain NaNs.',)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f78049af470e8fb847e6e9df03b091c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f78049af470e8fb847e6e9df03b091c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f78049af470e8fb847e6e9df03b091c = L.map(
#                 &quot;map_6f78049af470e8fb847e6e9df03b091c&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd57aa4db4a1b5a737718185d3c38870 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f78049af470e8fb847e6e9df03b091c);
#
#
#             var marker_972c8cd646d5e57bab11777de696a96a = L.marker(
#                 [23.082862, 120.587988],
#                 {}
#             ).addTo(map_6f78049af470e8fb847e6e9df03b091c);
#
#
#         var popup_7390259a6712c901effaa5d236590efe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5aafe236619f363f7a5a43d5b309fb9b = $(`&lt;div id=&quot;html_5aafe236619f363f7a5a43d5b309fb9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;甲仙林森&lt;/div&gt;`)[0];
#                 popup_7390259a6712c901effaa5d236590efe.setContent(html_5aafe236619f363f7a5a43d5b309fb9b);
#
#
#
#         marker_972c8cd646d5e57bab11777de696a96a.bindPopup(popup_7390259a6712c901effaa5d236590efe)
#         ;
#
#
#
#
#             var marker_d29dca1a7e18a765fa57875cb7112a45 = L.marker(
#                 [23.082262, 120.587394],
#                 {}
#             ).addTo(map_6f78049af470e8fb847e6e9df03b091c);
#
#
#         var popup_3b54aefe5f1bba1d2d29ddbcbd1fa8f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45927e29dc8b5174d30c21e993fdb36c = $(`&lt;div id=&quot;html_45927e29dc8b5174d30c21e993fdb36c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#                 popup_3b54aefe5f1bba1d2d29ddbcbd1fa8f0.setContent(html_45927e29dc8b5174d30c21e993fdb36c);
#
#
#
#         marker_d29dca1a7e18a765fa57875cb7112a45.bindPopup(popup_3b54aefe5f1bba1d2d29ddbcbd1fa8f0)
#         ;
#
#
#
#
#             var marker_1e5d2ab7d21f2599216966b9548f2b5b = L.marker(
#                 [22.96936, 120.54251],
#                 {}
#             ).addTo(map_6f78049af470e8fb847e6e9df03b091c);
#
#
#         var popup_55acd6f6d315f4550fc9bc4f481f949d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9663fc6fb3c1add10d7c10c18b5e7827 = $(`&lt;div id=&quot;html_9663fc6fb3c1add10d7c10c18b5e7827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大愛園區&lt;/div&gt;`)[0];
#                 popup_55acd6f6d315f4550fc9bc4f481f949d.setContent(html_9663fc6fb3c1add10d7c10c18b5e7827);
#
#
#
#         marker_1e5d2ab7d21f2599216966b9548f2b5b.bindPopup(popup_55acd6f6d315f4550fc9bc4f481f949d)
#         ;
#
#
#
#
#             var marker_198d50d4260e4a8c63523c2d638a013d = L.marker(
#                 [22.966443, 120.542328],
#                 {}
#             ).addTo(map_6f78049af470e8fb847e6e9df03b091c);
#
#
#         var popup_42fd1fa55b8b479582ab325f7b2319f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_605e21eb9f5ff8b99fe8c516b7d01050 = $(`&lt;div id=&quot;html_605e21eb9f5ff8b99fe8c516b7d01050&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#                 popup_42fd1fa55b8b479582ab325f7b2319f9.setContent(html_605e21eb9f5ff8b99fe8c516b7d01050);
#
#
#
#         marker_198d50d4260e4a8c63523c2d638a013d.bindPopup(popup_42fd1fa55b8b479582ab325f7b2319f9)
#         ;
#
#
#
#
#             var marker_85612e141ee2028ed4625b0f5bde0e96 = L.marker(
#                 [22.962941, 120.539572],
#                 {}
#             ).addTo(map_6f78049af470e8fb847e6e9df03b091c);
#
#
#         var popup_84f55b5d0c363e7eef4d6f2a87366605 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_651c262125eca4cbbbc58ac5630cc0e7 = $(`&lt;div id=&quot;html_651c262125eca4cbbbc58ac5630cc0e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#                 popup_84f55b5d0c363e7eef4d6f2a87366605.setContent(html_651c262125eca4cbbbc58ac5630cc0e7);
#
#
#
#         marker_85612e141ee2028ed4625b0f5bde0e96.bindPopup(popup_84f55b5d0c363e7eef4d6f2a87366605)
#         ;
#
#
#
#
#             var marker_9160ef3d94e0950aabc999b0882ce9eb = L.marker(
#                 [22.902712, 120.542015],
#                 {}
#             ).addTo(map_6f78049af470e8fb847e6e9df03b091c);
